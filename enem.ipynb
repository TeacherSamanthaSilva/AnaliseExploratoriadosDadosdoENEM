# %% [markdown]
# Análise Exploratória dos Dados do ENEM

# %% [markdown]
# Este notebook realiza uma Análise Exploratória de Dados (EDA) dos microdados do ENEM, com foco em identificar fatores associados ao desempenho em Matemática.

# %% [markdown]
# Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")
# Out:
# Matplotlib is building the font cache; this may take a moment.
